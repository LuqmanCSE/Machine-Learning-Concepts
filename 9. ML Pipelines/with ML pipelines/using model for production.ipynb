# %%
import pickle 
import numpy as np
import pandas as pd

# %%
pipe = pickle.load(open('pipe.pkl','rb'))

# %%
input_df = pd.DataFrame([[1,'female',42,0,,95,'S']],
                       columns=['Pclass','Sex','Age','SibSp','Parch','Fare','Embarked'])

# %%
pipe.predict(input_df)
# Out:
# array([1])
