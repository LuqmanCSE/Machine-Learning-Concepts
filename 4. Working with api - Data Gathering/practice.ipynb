# %%
import http.client

conn = http.client.HTTPSConnection("google-map-places-new-v2.p.rapidapi.com")

payload = "{\"input\":\"Restaurant\",\"locationBias\":{\"circle\":{\"center\":{\"latitude\":40,\"longitude\":-110},\"radius\":10000}},\"includedPrimaryTypes\":[],\"includedRegionCodes\":[],\"languageCode\":\"\",\"regionCode\":\"\",\"origin\":{\"latitude\":0,\"longitude\":0},\"inputOffset\":0,\"includeQueryPredictions\":true,\"sessionToken\":\"\"}"

headers = {
    'x-rapidapi-key': "42989d5428msh49eee5d185a2bcap14e2f5jsnd63063a291dc",
    'x-rapidapi-host': "google-map-places-new-v2.p.rapidapi.com",
    'Content-Type': "application/json",
    'X-Goog-FieldMask': "*"
}

conn.request("POST", "/v1/places:autocomplete", payload, headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# Oops, an error in the gateway has occurred. If the issue persists, please contact support@rapidapi.com
