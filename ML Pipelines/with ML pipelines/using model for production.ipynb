# %%
import pickle 
import numpy as np

# %%
pipe = pickle.load(open('pipe.pkl','rb'))

# %%
input = np.array([1.0,0.0,0.0,30.000,22.000000,'S','male'],dtype=object).reshape(1,7)

# %%
pipe.predict(input)
# Out:
# C:\Users\luqma\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# C:\Users\luqma\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])

# %%
### Note: Feature scaling(T4) has made the accuracy extreamly low
